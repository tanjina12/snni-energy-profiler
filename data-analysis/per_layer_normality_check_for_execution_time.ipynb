# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %%
# Load the dataset for Execution Time Conv-1 to Conv-53
data_et = pd.read_csv("/Users/tanjina/Desktop/New-readings/output-with-sleep-power-reading/client/analysis/per_layer_execution_time_sleep_3s_30_runs.csv")

# %%
# Normality check
# density plot of the distribution of Execution Time for Conv layer - 1
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_1'].min(), data_et['conv_layer_1'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_1'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_1'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 1')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 1
shapiro_et_conv_1 = stats.shapiro(data_et['conv_layer_1'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 1: W = {shapiro_et_conv_1.statistic:.4f}, p-value = {shapiro_et_conv_1.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 2
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_2'].min(), data_et['conv_layer_2'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_2'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_2'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 2')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 2
shapiro_et_conv_2 = stats.shapiro(data_et['conv_layer_2'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 2: W = {shapiro_et_conv_2.statistic:.4f}, p-value = {shapiro_et_conv_2.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 3
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_3'].min(), data_et['conv_layer_3'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_3'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_3'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 3')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 3
shapiro_et_conv_3 = stats.shapiro(data_et['conv_layer_3'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 3: W = {shapiro_et_conv_3.statistic:.4f}, p-value = {shapiro_et_conv_3.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 4
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_4'].min(), data_et['conv_layer_4'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_4'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_4'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 4')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 4
shapiro_et_conv_4 = stats.shapiro(data_et['conv_layer_4'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 4: W = {shapiro_et_conv_4.statistic:.4f}, p-value = {shapiro_et_conv_4.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 5
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_5'].min(), data_et['conv_layer_5'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_5'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_5'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 5')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 5
shapiro_et_conv_5 = stats.shapiro(data_et['conv_layer_5'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 5: W = {shapiro_et_conv_5.statistic:.4f}, p-value = {shapiro_et_conv_5.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 6
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_6'].min(), data_et['conv_layer_6'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_6'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_6'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 6')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 6
shapiro_et_conv_6 = stats.shapiro(data_et['conv_layer_6'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 6: W = {shapiro_et_conv_6.statistic:.4f}, p-value = {shapiro_et_conv_6.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 7
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_7'].min(), data_et['conv_layer_7'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_7'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_7'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 7')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 7
shapiro_et_conv_7 = stats.shapiro(data_et['conv_layer_7'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 7: W = {shapiro_et_conv_7.statistic:.4f}, p-value = {shapiro_et_conv_7.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 8
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_8'].min(), data_et['conv_layer_8'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_8'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_8'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 8')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 8
shapiro_et_conv_8 = stats.shapiro(data_et['conv_layer_8'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 8: W = {shapiro_et_conv_8.statistic:.4f}, p-value = {shapiro_et_conv_8.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 9
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_9'].min(), data_et['conv_layer_9'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_9'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_9'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 9')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 9
shapiro_et_conv_9 = stats.shapiro(data_et['conv_layer_9'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 9: W = {shapiro_et_conv_9.statistic:.4f}, p-value = {shapiro_et_conv_9.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 10
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_10'].min(), data_et['conv_layer_10'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_10'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_10'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 10')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 10
shapiro_et_conv_10 = stats.shapiro(data_et['conv_layer_10'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 10: W = {shapiro_et_conv_10.statistic:.4f}, p-value = {shapiro_et_conv_10.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 11
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_11'].min(), data_et['conv_layer_11'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_11'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_11'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 11')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 11
shapiro_et_conv_11 = stats.shapiro(data_et['conv_layer_11'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 11: W = {shapiro_et_conv_11.statistic:.4f}, p-value = {shapiro_et_conv_11.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 12
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_12'].min(), data_et['conv_layer_12'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_12'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_12'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 12')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 12
shapiro_et_conv_12 = stats.shapiro(data_et['conv_layer_12'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 12: W = {shapiro_et_conv_12.statistic:.4f}, p-value = {shapiro_et_conv_12.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 13
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_13'].min(), data_et['conv_layer_13'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_13'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_13'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 13')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 13
shapiro_et_conv_13 = stats.shapiro(data_et['conv_layer_13'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 13: W = {shapiro_et_conv_13.statistic:.4f}, p-value = {shapiro_et_conv_13.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 14
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_14'].min(), data_et['conv_layer_14'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_14'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_14'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 14')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 14
shapiro_et_conv_14 = stats.shapiro(data_et['conv_layer_14'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 14: W = {shapiro_et_conv_14.statistic:.4f}, p-value = {shapiro_et_conv_14.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 15
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_15'].min(), data_et['conv_layer_15'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_15'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_15'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 15')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 15
shapiro_et_conv_15 = stats.shapiro(data_et['conv_layer_15'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 15: W = {shapiro_et_conv_15.statistic:.4f}, p-value = {shapiro_et_conv_15.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 16
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_16'].min(), data_et['conv_layer_16'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_16'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_16'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 16')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 16
shapiro_et_conv_16 = stats.shapiro(data_et['conv_layer_16'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 16: W = {shapiro_et_conv_16.statistic:.4f}, p-value = {shapiro_et_conv_16.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 17
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_17'].min(), data_et['conv_layer_17'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_17'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_17'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 17')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 17
shapiro_et_conv_17 = stats.shapiro(data_et['conv_layer_17'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 17: W = {shapiro_et_conv_17.statistic:.4f}, p-value = {shapiro_et_conv_17.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 18
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_18'].min(), data_et['conv_layer_18'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_18'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_18'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 18')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 18
shapiro_et_conv_18 = stats.shapiro(data_et['conv_layer_18'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 18: W = {shapiro_et_conv_18.statistic:.4f}, p-value = {shapiro_et_conv_18.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 19
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_19'].min(), data_et['conv_layer_19'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_19'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_19'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 19')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 19
shapiro_et_conv_19 = stats.shapiro(data_et['conv_layer_19'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 19: W = {shapiro_et_conv_19.statistic:.4f}, p-value = {shapiro_et_conv_19.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 20
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_20'].min(), data_et['conv_layer_20'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_20'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_20'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 20')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 20
shapiro_et_conv_20 = stats.shapiro(data_et['conv_layer_20'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 20: W = {shapiro_et_conv_20.statistic:.4f}, p-value = {shapiro_et_conv_20.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 21
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_21'].min(), data_et['conv_layer_21'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_21'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_21'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 21')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 21
shapiro_et_conv_21 = stats.shapiro(data_et['conv_layer_21'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 21: W = {shapiro_et_conv_21.statistic:.4f}, p-value = {shapiro_et_conv_21.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 22
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_22'].min(), data_et['conv_layer_22'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_22'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_22'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 22')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 22
shapiro_et_conv_22 = stats.shapiro(data_et['conv_layer_22'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 22: W = {shapiro_et_conv_22.statistic:.4f}, p-value = {shapiro_et_conv_22.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 23
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_23'].min(), data_et['conv_layer_23'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_23'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_23'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 23')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 23
shapiro_et_conv_23 = stats.shapiro(data_et['conv_layer_23'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 23: W = {shapiro_et_conv_23.statistic:.4f}, p-value = {shapiro_et_conv_23.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 24
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_24'].min(), data_et['conv_layer_24'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_24'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_24'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 24')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 24
shapiro_et_conv_24 = stats.shapiro(data_et['conv_layer_24'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 24: W = {shapiro_et_conv_24.statistic:.4f}, p-value = {shapiro_et_conv_24.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 25
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_25'].min(), data_et['conv_layer_25'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_25'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_25'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 25')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 25
shapiro_et_conv_25 = stats.shapiro(data_et['conv_layer_25'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 25: W = {shapiro_et_conv_25.statistic:.4f}, p-value = {shapiro_et_conv_25.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 26
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_26'].min(), data_et['conv_layer_26'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_26'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_26'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 26')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 26
shapiro_et_conv_26 = stats.shapiro(data_et['conv_layer_26'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 26: W = {shapiro_et_conv_26.statistic:.4f}, p-value = {shapiro_et_conv_26.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 27
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_27'].min(), data_et['conv_layer_27'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_27'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_27'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 27')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 27
shapiro_et_conv_27 = stats.shapiro(data_et['conv_layer_27'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 27: W = {shapiro_et_conv_27.statistic:.4f}, p-value = {shapiro_et_conv_27.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 28
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_28'].min(), data_et['conv_layer_28'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_28'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_28'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 28')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 28
shapiro_et_conv_28 = stats.shapiro(data_et['conv_layer_28'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 28: W = {shapiro_et_conv_28.statistic:.4f}, p-value = {shapiro_et_conv_28.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 29
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_29'].min(), data_et['conv_layer_29'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_29'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_29'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 29')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 29
shapiro_et_conv_29 = stats.shapiro(data_et['conv_layer_29'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 1: W = {shapiro_et_conv_29.statistic:.4f}, p-value = {shapiro_et_conv_29.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 30
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_30'].min(), data_et['conv_layer_30'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_30'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_30'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 30')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 30
shapiro_et_conv_30 = stats.shapiro(data_et['conv_layer_30'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 30: W = {shapiro_et_conv_30.statistic:.4f}, p-value = {shapiro_et_conv_30.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 31
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_31'].min(), data_et['conv_layer_31'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_31'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_31'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 31')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 31
shapiro_et_conv_31 = stats.shapiro(data_et['conv_layer_31'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 31: W = {shapiro_et_conv_31.statistic:.4f}, p-value = {shapiro_et_conv_31.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 32
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_32'].min(), data_et['conv_layer_32'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_32'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_32'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 32')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 32
shapiro_et_conv_32 = stats.shapiro(data_et['conv_layer_32'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 32: W = {shapiro_et_conv_32.statistic:.4f}, p-value = {shapiro_et_conv_32.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 33
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_33'].min(), data_et['conv_layer_33'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_33'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_33'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 33')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 33
shapiro_et_conv_33 = stats.shapiro(data_et['conv_layer_33'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 33: W = {shapiro_et_conv_33.statistic:.4f}, p-value = {shapiro_et_conv_33.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 34
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_34'].min(), data_et['conv_layer_34'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_34'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_34'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 34')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 34
shapiro_et_conv_34 = stats.shapiro(data_et['conv_layer_34'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 34: W = {shapiro_et_conv_34.statistic:.4f}, p-value = {shapiro_et_conv_34.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 35
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_35'].min(), data_et['conv_layer_35'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_35'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_35'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 35')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 35
shapiro_et_conv_35 = stats.shapiro(data_et['conv_layer_35'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 35: W = {shapiro_et_conv_35.statistic:.4f}, p-value = {shapiro_et_conv_35.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 36
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_36'].min(), data_et['conv_layer_36'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_36'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_36'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 36')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 36
shapiro_et_conv_36 = stats.shapiro(data_et['conv_layer_36'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 36: W = {shapiro_et_conv_36.statistic:.4f}, p-value = {shapiro_et_conv_36.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 37
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_37'].min(), data_et['conv_layer_37'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_37'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_37'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 37')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 37
shapiro_et_conv_37 = stats.shapiro(data_et['conv_layer_37'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 37: W = {shapiro_et_conv_37.statistic:.4f}, p-value = {shapiro_et_conv_37.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 38
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_38'].min(), data_et['conv_layer_38'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_38'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_38'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 38')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 38
shapiro_et_conv_38 = stats.shapiro(data_et['conv_layer_38'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 38: W = {shapiro_et_conv_38.statistic:.4f}, p-value = {shapiro_et_conv_38.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 39
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_39'].min(), data_et['conv_layer_39'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_39'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_39'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 39')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 39
shapiro_et_conv_39 = stats.shapiro(data_et['conv_layer_39'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 39: W = {shapiro_et_conv_39.statistic:.4f}, p-value = {shapiro_et_conv_39.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 40
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_40'].min(), data_et['conv_layer_40'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_40'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_40'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 40')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 40
shapiro_et_conv_40 = stats.shapiro(data_et['conv_layer_40'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 40: W = {shapiro_et_conv_40.statistic:.4f}, p-value = {shapiro_et_conv_40.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 41
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_41'].min(), data_et['conv_layer_41'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_41'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_41'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 41')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 41
shapiro_et_conv_41 = stats.shapiro(data_et['conv_layer_41'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 41: W = {shapiro_et_conv_41.statistic:.4f}, p-value = {shapiro_et_conv_41.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 42
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_42'].min(), data_et['conv_layer_42'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_42'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_42'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 42')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 42
shapiro_et_conv_42 = stats.shapiro(data_et['conv_layer_42'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 42: W = {shapiro_et_conv_42.statistic:.4f}, p-value = {shapiro_et_conv_42.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 43
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_43'].min(), data_et['conv_layer_43'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_43'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_43'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 43')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 43
shapiro_et_conv_43 = stats.shapiro(data_et['conv_layer_43'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 43: W = {shapiro_et_conv_43.statistic:.4f}, p-value = {shapiro_et_conv_43.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 44
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_44'].min(), data_et['conv_layer_44'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_44'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_44'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 44')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 44
shapiro_et_conv_44 = stats.shapiro(data_et['conv_layer_44'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 44: W = {shapiro_et_conv_44.statistic:.4f}, p-value = {shapiro_et_conv_44.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 45
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_45'].min(), data_et['conv_layer_45'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_45'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_45'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 45')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 45
shapiro_et_conv_45 = stats.shapiro(data_et['conv_layer_45'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 45: W = {shapiro_et_conv_45.statistic:.4f}, p-value = {shapiro_et_conv_45.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 46
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_46'].min(), data_et['conv_layer_46'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_46'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_46'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 46')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 46
shapiro_et_conv_46 = stats.shapiro(data_et['conv_layer_46'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 46: W = {shapiro_et_conv_46.statistic:.4f}, p-value = {shapiro_et_conv_46.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 47
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_47'].min(), data_et['conv_layer_47'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_47'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_47'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 47')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 47
shapiro_et_conv_47 = stats.shapiro(data_et['conv_layer_47'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 47: W = {shapiro_et_conv_47.statistic:.4f}, p-value = {shapiro_et_conv_47.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 48
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_48'].min(), data_et['conv_layer_48'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_48'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_48'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 48')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 48
shapiro_et_conv_48 = stats.shapiro(data_et['conv_layer_48'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 48: W = {shapiro_et_conv_48.statistic:.4f}, p-value = {shapiro_et_conv_48.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 49
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_49'].min(), data_et['conv_layer_49'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_49'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_49'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 49')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 49
shapiro_et_conv_49 = stats.shapiro(data_et['conv_layer_49'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 49: W = {shapiro_et_conv_49.statistic:.4f}, p-value = {shapiro_et_conv_49.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 50
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_50'].min(), data_et['conv_layer_50'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_50'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_50'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 50')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 50
shapiro_et_conv_50 = stats.shapiro(data_et['conv_layer_50'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 50: W = {shapiro_et_conv_50.statistic:.4f}, p-value = {shapiro_et_conv_50.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 51
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_51'].min(), data_et['conv_layer_51'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_51'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_51'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 51')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 51
shapiro_et_conv_51 = stats.shapiro(data_et['conv_layer_51'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 51: W = {shapiro_et_conv_51.statistic:.4f}, p-value = {shapiro_et_conv_51.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 52
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_52'].min(), data_et['conv_layer_52'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_52'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_52'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 52')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 52
shapiro_et_conv_52 = stats.shapiro(data_et['conv_layer_52'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 52: W = {shapiro_et_conv_52.statistic:.4f}, p-value = {shapiro_et_conv_52.pvalue:.4f}")

# density plot of the distribution of Execution Time for Conv layer - 53
# Define bin width (e.g., 5ms or 10ms)
bin_width = 5  # Change to 5 for finer binning
bin_edges = np.arange(data_et['conv_layer_53'].min(), data_et['conv_layer_53'].max() + bin_width, bin_width)

# Plot histogram with custom bin edges
plt.figure(figsize=(8, 4))
sns.histplot(data_et['conv_layer_53'], kde=True, bins=bin_edges, color='black')

# plt.figure(figsize=(8, 4))
# sns.histplot(data_et['conv_layer_53'], kde=True, bins=15, color='black')
plt.title('Distribution of the density of Execution Time for Conv layer# 53')
plt.xlabel('Execution Time (ms)')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# Shapiro-Wilk test for Execution Time for Conv layer - 53
shapiro_et_conv_53 = stats.shapiro(data_et['conv_layer_53'])
print(f"Shapiro-Wilk Test for Execution Time for Conv layer# 53: W = {shapiro_et_conv_53.statistic:.4f}, p-value = {shapiro_et_conv_53.pvalue:.4f}")
# Out:
# Shapiro-Wilk Test for Execution Time for Conv layer# 1: W = 0.7611, p-value = 0.0000
# Shapiro-Wilk Test for Execution Time for Conv layer# 2: W = 0.9005, p-value = 0.0087
# Shapiro-Wilk Test for Execution Time for Conv layer# 3: W = 0.9163, p-value = 0.0216
# Shapiro-Wilk Test for Execution Time for Conv layer# 4: W = 0.9100, p-value = 0.0149
# Shapiro-Wilk Test for Execution Time for Conv layer# 5: W = 0.6881, p-value = 0.0000
# Shapiro-Wilk Test for Execution Time for Conv layer# 6: W = 0.9402, p-value = 0.0920
# Shapiro-Wilk Test for Execution Time for Conv layer# 7: W = 0.1959, p-value = 0.0000
# Shapiro-Wilk Test for Execution Time for Conv layer# 8: W = 0.7451, p-value = 0.0000
# Shapiro-Wilk Test for Execution Time for Conv layer# 9: W = 0.9622, p-value = 0.3521
# Shapiro-Wilk Test for Execution Time for Conv layer# 10: W = 0.8584, p-value = 0.0009
# Shapiro-Wilk Test for Execution Time for Conv layer# 11: W = 0.6933, p-value = 0.0000
# ...
